# %% [markdown]
# ## El juego de la vida
# Las reglas de este juego son las siguientes:
#
#     1. Una persona nace si tiene alrededor cierta cantidad de personas que depende de la tasa de natalidad
#     2. Una persona muere si tiene alrededor cierta cantidad de personas que depende de la tasa de mortalidad
#     3. Una persona sobrevive si tiene alrededor cierta cantidad de personas que depende de la tasa de supervivencia

# %%
# importamos las bibliotecas que vamos a usar para la animacion

from time import sleep

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib import animation
from matplotlib.animation import FuncAnimation, PillowWriter  
# %matplotlib notebook

import random

# definimos el movimiento de juego por iteracion
def mover(juego):
    
    for i in range(len(juego)):
        for j in range(len(juego)):
            mortalidad=2
            natalidad=3
            supervivencia=1
            
            if i == 0 and j == 0:
                sum=0
                der= np.roll(juego,shift=-1,axis=1)
                sum=sum+der[i,j]
                inf= np.roll(juego,shift=-1,axis=0)
                sum=sum+inf[i,j]
                derinf= np.roll(inf,shift=-1,axis=1)
                sum=sum+derinf[i,j]
                if juego[i,j] == 0:
                    if sum >= natalidad:
                        nuevo[i,j]=1
                else:
                    if sum >= mortalidad or sum < supervivencia:
                        nuevo[i,j]=0
                    else:
                        nuevo[i,j]=1
            if i == 0 and j <= (len(juego)-2):
                sum=0
                izq= np.roll(juego,shift=1,axis=1)
                sum=sum+izq[i,j]
                der= np.roll(juego,shift=-1,axis=1)
                sum=sum+der[i,j]
                inf= np.roll(juego,shift=-1,axis=0)
                sum=sum+inf[i,j]
                izqinf= np.roll(izq,shift=-1,axis=0)
                sum=sum+izqinf[i,j]
                derinf= np.roll(inf,shift=-1,axis=1)
                sum=sum+derinf[i,j]
                if juego[i,j] == 0:
                    if sum >= natalidad:
                        nuevo[i,j]=1
                else:
                    if sum >= mortalidad or sum < supervivencia:
                        nuevo[i,j]=0
                    else:
                        nuevo[i,j]=1
            if i == 0 and j == (len(juego)-1):
                sum=0
                izq= np.roll(juego,shift=1,axis=1)
                sum=sum+izq[i,j]
                inf= np.roll(juego,shift=-1,axis=0)
                sum=sum+inf[i,j]
                izqinf= np.roll(izq,shift=-1,axis=0)
                sum=sum+izqinf[i,j]
                if juego[i,j] == 0:
                    if sum >= natalidad:
                        nuevo[i,j]=1
                else:
                    if sum >= mortalidad or sum < supervivencia:
                        nuevo[i,j]=0
                    else:
                        nuevo[i,j]=1
            if i <= (len(juego)-2) and i != 0 and j==0:
                sum=0
                der= np.roll(juego,shift=-1,axis=1)
                sum=sum+der[i,j]
                sup= np.roll(juego,shift=1,axis=0)
                sum=sum+sup[i,j]
                inf= np.roll(juego,shift=-1,axis=0)
                sum=sum+inf[i,j]
                dersup= np.roll(der,shift=1,axis=0)
                sum=sum+dersup[i,j]
                derinf= np.roll(inf,shift=-1,axis=1)
                sum=sum+derinf[i,j]
                if juego[i,j] == 0:
                    if sum >= natalidad:
                        nuevo[i,j]=1
                else:
                    if sum >= mortalidad or sum < supervivencia:
                        nuevo[i,j]=0
                    else:
                        nuevo[i,j]=1
            if i ==(len(juego)-1) and j ==0:
                sum=0
                der= np.roll(juego,shift=-1,axis=1)
                sum=sum+der[i,j]
                sup= np.roll(juego,shift=1,axis=0)
                sum=sum+sup[i,j]
                dersup= np.roll(der,shift=1,axis=0)
                sum=sum+dersup[i,j]
                if juego[i,j] == 0:
                    if sum >= natalidad:
                        nuevo[i,j]=1
                else:
                    if sum >= mortalidad or sum < supervivencia:
                        nuevo[i,j]=0
                    else:
                        nuevo[i,j]=1
            if i ==(len(juego)-1) and j <=(len(juego)-2) and j != 0:
                sum=0
                izq= np.roll(juego,shift=1,axis=1)
                sum=sum+izq[i,j]
                der= np.roll(juego,shift=-1,axis=1)
                sum=sum+der[i,j]
                sup= np.roll(juego,shift=1,axis=0)
                sum=sum+sup[i,j]
                izqsup= np.roll(izq,shift=1,axis=0)
                sum=sum+izqsup[i,j]
                dersup= np.roll(der,shift=1,axis=0)
                sum=sum+dersup[i,j]
                if juego[i,j] == 0:
                    if sum >= natalidad:
                        nuevo[i,j]=1
                else:
                    if sum >= mortalidad or sum < supervivencia:
                        nuevo[i,j]=0
                    else:
                        nuevo[i,j]=1
            if i == (len(juego)-1) and j == (len(juego)-1):
                sum=0
                izq= np.roll(juego,shift=1,axis=1)
                sum=sum+izq[i,j]
                sup= np.roll(juego,shift=1,axis=0)
                sum=sum+sup[i,j]
                izqsup= np.roll(izq,shift=1,axis=0)
                sum=sum+izqsup[i,j]
                if juego[i,j] == 0:
                    if sum >= natalidad:
                        nuevo[i,j]=1
                else:
                    if sum >= mortalidad or sum < supervivencia:
                        nuevo[i,j]=0
                    else:
                        nuevo[i,j]=1
            if i != 0 and i != (len(juego)-1) and j != 0 and j != (len(juego)-1):
                sum=0
                izq= np.roll(juego,shift=1,axis=1)
                sum=sum+izq[i,j]
                der= np.roll(juego,shift=-1,axis=1)
                sum=sum+der[i,j]
                sup= np.roll(juego,shift=1,axis=0)
                sum=sum+sup[i,j]
                inf= np.roll(juego,shift=-1,axis=0)
                sum=sum+inf[i,j]
                izqsup= np.roll(izq,shift=1,axis=0)
                sum=sum+izqsup[i,j]
                dersup= np.roll(der,shift=1,axis=0)
                sum=sum+dersup[i,j]
                izqinf= np.roll(izq,shift=-1,axis=0)
                sum=sum+izqinf[i,j]
                derinf= np.roll(inf,shift=-1,axis=1)
                sum=sum+derinf[i,j]
                if juego[i,j] == 0:
                    if sum >= natalidad:
                        nuevo[i,j]=1
                else:
                    if sum >= mortalidad or sum < supervivencia:
                        nuevo[i,j]=0
                    else:
                        nuevo[i,j]=1
    return nuevo

# Se define el lienzo o base para hacer la animacion
juego=np.random.randint(2, size=(16, 16)) #se hace el tablero inicial para correr el juego
nuevo=np.zeros((16,16))
# Se hace el lienzo
fig = plt.figure(figsize=(4, 4))
ax = fig.add_subplot(111)
copia=juego
# se grafica la imagen inicial y sus modificaciones
imagen = ax.imshow(juego, interpolation="none", aspect = "equal", cmap=cm.gray_r)

# Se define la animacion
def animate(i):
    global juego
    print(i)
    juego=mover(juego)
    imagen.set_data(juego)
    return imagen,
# Funcion que llama la animacion para hacer iteraciones
anim = animation.FuncAnimation(fig, animate, frames=1, blit=True, interval = 800, repeat = True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
# Codigo para sacar los muertos y vivos al pasar el tiempo
mortalidad=2
natalidad=3
supervivencia=1
iteraciones=20
vivos = []
muertos = []
nacimientos= []
muert = []
temp1=0
temp=0
juego=copia
for k in range (iteraciones):
    
#     se calculan los datos para graficar
    vivos.append(np.sum(juego))
    nacimientos.append(temp)
    muert.append(temp1)
    muertos.append((len(juego)*len(juego))-vivos[k])
    temp=0
    temp1=0
    
    for i in range(len(juego)):
        for j in range(len(juego)):
            
            if i == 0 and j == 0:
                sum=0
                der= np.roll(juego,shift=-1,axis=1)
                sum=sum+der[i,j]
                inf= np.roll(juego,shift=-1,axis=0)
                sum=sum+inf[i,j]
                derinf= np.roll(inf,shift=-1,axis=1)
                sum=sum+derinf[i,j]
                if juego[i,j] == 0:
                    if sum >= natalidad:
                        nuevo[i,j]=1
                        temp=temp+1
                else:
                    if sum >= mortalidad or sum < supervivencia:
                        nuevo[i,j]=0
                        temp1=temp1+1
                    else:
                        nuevo[i,j]=1
                        temp=temp+1
            if i == 0 and j <= (len(juego)-2):
                sum=0
                izq= np.roll(juego,shift=1,axis=1)
                sum=sum+izq[i,j]
                der= np.roll(juego,shift=-1,axis=1)
                sum=sum+der[i,j]
                inf= np.roll(juego,shift=-1,axis=0)
                sum=sum+inf[i,j]
                izqinf= np.roll(izq,shift=-1,axis=0)
                sum=sum+izqinf[i,j]
                derinf= np.roll(inf,shift=-1,axis=1)
                sum=sum+derinf[i,j]
                if juego[i,j] == 0:
                    if sum >= natalidad:
                        nuevo[i,j]=1
                        temp=temp+1
                else:
                    if sum >= mortalidad or sum < supervivencia:
                        nuevo[i,j]=0
                        temp1=temp1+1
                    else:
                        nuevo[i,j]=1
                        temp=temp+1
            if i == 0 and j == (len(juego)-1):
                sum=0
                izq= np.roll(juego,shift=1,axis=1)
                sum=sum+izq[i,j]
                inf= np.roll(juego,shift=-1,axis=0)
                sum=sum+inf[i,j]
                izqinf= np.roll(izq,shift=-1,axis=0)
                sum=sum+izqinf[i,j]
                if juego[i,j] == 0:
                    if sum >= natalidad:
                        nuevo[i,j]=1
                        temp=temp+1
                else:
                    if sum >= mortalidad or sum < supervivencia:
                        nuevo[i,j]=0
                        temp1=temp1+1
                    else:
                        nuevo[i,j]=1
                        temp=temp+1
            if i <= (len(juego)-2) and i != 0 and j==0:
                sum=0
                der= np.roll(juego,shift=-1,axis=1)
                sum=sum+der[i,j]
                sup= np.roll(juego,shift=1,axis=0)
                sum=sum+sup[i,j]
                inf= np.roll(juego,shift=-1,axis=0)
                sum=sum+inf[i,j]
                dersup= np.roll(der,shift=1,axis=0)
                sum=sum+dersup[i,j]
                derinf= np.roll(inf,shift=-1,axis=1)
                sum=sum+derinf[i,j]
                if juego[i,j] == 0:
                    if sum >= natalidad:
                        nuevo[i,j]=1
                        temp=temp+1
                else:
                    if sum >= mortalidad or sum < supervivencia:
                        nuevo[i,j]=0
                        temp1=temp1+1
                    else:
                        nuevo[i,j]=1
                        temp=temp+1
            if i ==(len(juego)-1) and j ==0:
                sum=0
                der= np.roll(juego,shift=-1,axis=1)
                sum=sum+der[i,j]
                sup= np.roll(juego,shift=1,axis=0)
                sum=sum+sup[i,j]
                dersup= np.roll(der,shift=1,axis=0)
                sum=sum+dersup[i,j]
                if juego[i,j] == 0:
                    if sum >= natalidad:
                        nuevo[i,j]=1
                        temp=temp+1
                else:
                    if sum >= mortalidad or sum < supervivencia:
                        nuevo[i,j]=0
                        temp1=temp1+1
                    else:
                        nuevo[i,j]=1
                        temp=temp+1
            if i ==(len(juego)-1) and j <=(len(juego)-2) and j != 0:
                sum=0
                izq= np.roll(juego,shift=1,axis=1)
                sum=sum+izq[i,j]
                der= np.roll(juego,shift=-1,axis=1)
                sum=sum+der[i,j]
                sup= np.roll(juego,shift=1,axis=0)
                sum=sum+sup[i,j]
                izqsup= np.roll(izq,shift=1,axis=0)
                sum=sum+izqsup[i,j]
                dersup= np.roll(der,shift=1,axis=0)
                sum=sum+dersup[i,j]
                if juego[i,j] == 0:
                    if sum >= natalidad:
                        nuevo[i,j]=1
                        temp=temp+1
                else:
                    if sum >= mortalidad or sum < supervivencia:
                        nuevo[i,j]=0
                        temp1=temp1+1
                    else:
                        nuevo[i,j]=1
                        temp=temp+1
            if i == (len(juego)-1) and j == (len(juego)-1):
                sum=0
                izq= np.roll(juego,shift=1,axis=1)
                sum=sum+izq[i,j]
                sup= np.roll(juego,shift=1,axis=0)
                sum=sum+sup[i,j]
                izqsup= np.roll(izq,shift=1,axis=0)
                sum=sum+izqsup[i,j]
                if juego[i,j] == 0:
                    if sum >= natalidad:
                        nuevo[i,j]=1
                        temp=temp+1
                else:
                    if sum >= mortalidad or sum < supervivencia:
                        nuevo[i,j]=0
                        temp1=temp1+1
                    else:
                        nuevo[i,j]=1
                        temp=temp+1
            if i != 0 and i != (len(juego)-1) and j != 0 and j != (len(juego)-1):
                sum=0
                izq= np.roll(juego,shift=1,axis=1)
                sum=sum+izq[i,j]
                der= np.roll(juego,shift=-1,axis=1)
                sum=sum+der[i,j]
                sup= np.roll(juego,shift=1,axis=0)
                sum=sum+sup[i,j]
                inf= np.roll(juego,shift=-1,axis=0)
                sum=sum+inf[i,j]
                izqsup= np.roll(izq,shift=1,axis=0)
                sum=sum+izqsup[i,j]
                dersup= np.roll(der,shift=1,axis=0)
                sum=sum+dersup[i,j]
                izqinf= np.roll(izq,shift=-1,axis=0)
                sum=sum+izqinf[i,j]
                derinf= np.roll(inf,shift=-1,axis=1)
                sum=sum+derinf[i,j]
                if juego[i,j] == 0:
                    if sum >= natalidad:
                        nuevo[i,j]=1
                        temp=temp+1
                else:
                    if sum >= mortalidad or sum < supervivencia:
                        nuevo[i,j]=0
                        temp1=temp1+1
                    else:
                        nuevo[i,j]=1
                        temp=temp+1
        
    juego=nuevo
    
# Graficamos los datos
plt.figure()
plt.plot(vivos,"b", label = "Sobrevivientes")
plt.plot(muertos,"r", label = "Sin poblacion")
plt.plot(nacimientos,"g", label = "Natalidad")
plt.plot(muert,"k", label = "Mortalidad")
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">
